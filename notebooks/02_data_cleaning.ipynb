# %% [markdown]
# # 02 - Data Cleaning
#
# Starter notebook for cleaning, validating, and preparing churn data for EDA and modeling.

# %%
from churn_ml.data.clean_data import clean_churn_data
from churn_ml.data.load_data import load_raw_data

raw_df = load_raw_data()
clean_df = clean_churn_data(raw_df)
clean_df.head()
