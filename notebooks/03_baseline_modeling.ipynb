# %% [markdown]
# # 03 - Baseline Modeling
#
# Starter notebook for interpretable baseline modeling. Final model training is intentionally deferred.

# %%
from churn_ml.data.clean_data import clean_churn_data
from churn_ml.data.load_data import load_raw_data
from churn_ml.models.train_model import train_baseline_logistic_regression

raw_df = load_raw_data()
clean_df = clean_churn_data(raw_df)
# model = train_baseline_logistic_regression(clean_df)
