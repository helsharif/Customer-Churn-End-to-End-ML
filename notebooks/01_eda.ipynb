# %% [markdown]
# # 01 - Exploratory Data Analysis
#
# Initial EDA notebook for the IBM Telco customer churn dataset.

# %%
from churn_ml.data.load_data import load_raw_data

df = load_raw_data()
df.head()
